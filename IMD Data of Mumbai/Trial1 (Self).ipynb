# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("MAHARASHTRA_MUMBAI_CITY_MUMBAI_COLABA_18.8978_72.8128_11.98_2017-01-01_2022-08-10_AWS.csv")

# %%
data1.head()
# Out:
#          DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  \
# 0  2017-01-19  06:00:00              0.0             0.0     47.6
# 1  2017-01-19  07:00:00              NaN             0.0      NaN
# 2  2017-01-19  08:00:00              5.0             5.0     28.4
# 3  2017-01-19  09:00:00              0.0             5.0     27.9
# 4  2017-01-19  10:00:00              NaN             5.0     27.5
#
#    TEMP_MIN(C)  TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  \
# 0          9.9         50.2                  NaN          35.5   52.0
# 1          NaN          NaN                  NaN           NaN    NaN
# 2         28.0         28.5                  NaN          17.3   51.0
# 3         27.9         28.5                  NaN          19.4   60.0
# 4         27.6         27.9                  NaN          21.8   71.0
#
#    WIND_DIR(deg)  WIND_SPEED(kt)  SLP(hPa)  MSLP(hPa)  SUNSHINE  Unnamed: 15
# ...

# %%
data1["date_time"]=data1["DATE"]+" "+data1["TIME(UTC)"]

# %%
data1.head()
# Out:
#          DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  \
# 0  2017-01-19  06:00:00              0.0             0.0     47.6
# 1  2017-01-19  07:00:00              NaN             0.0      NaN
# 2  2017-01-19  08:00:00              5.0             5.0     28.4
# 3  2017-01-19  09:00:00              0.0             5.0     27.9
# 4  2017-01-19  10:00:00              NaN             5.0     27.5
#
#    TEMP_MIN(C)  TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  \
# 0          9.9         50.2                  NaN          35.5   52.0
# 1          NaN          NaN                  NaN           NaN    NaN
# 2         28.0         28.5                  NaN          17.3   51.0
# 3         27.9         28.5                  NaN          19.4   60.0
# 4         27.6         27.9                  NaN          21.8   71.0
#
#    WIND_DIR(deg)  WIND_SPEED(kt)  SLP(hPa)  MSLP(hPa)  SUNSHINE  Unnamed: 15  \
# ...

# %%
data1.set_index("date_time")
# Out:
#                            DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  \
# date_time
# 2017-01-19 06:00:00  2017-01-19  06:00:00              0.0             0.0
# 2017-01-19 07:00:00  2017-01-19  07:00:00              NaN             0.0
# 2017-01-19 08:00:00  2017-01-19  08:00:00              5.0             5.0
# 2017-01-19 09:00:00  2017-01-19  09:00:00              0.0             5.0
# 2017-01-19 10:00:00  2017-01-19  10:00:00              NaN             5.0
# ...                         ...       ...              ...             ...
# 2017-12-31 10:00:00  2017-12-31  10:00:00              0.0             0.0
# 2017-12-31 11:00:00  2017-12-31  11:00:00             18.0             0.0
# 2017-12-31 12:00:00  2017-12-31  12:00:00              0.0             0.0
# 2017-12-31 13:00:00  2017-12-31  13:00:00              0.0             0.0
# 2017-12-31 14:00:00  2017-12-31  14:00:00              0.0             0.0
#
# ...

# %%
data1.head()
# Out:
#          DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  \
# 0  2017-01-19  06:00:00              0.0             0.0     47.6
# 1  2017-01-19  07:00:00              NaN             0.0      NaN
# 2  2017-01-19  08:00:00              5.0             5.0     28.4
# 3  2017-01-19  09:00:00              0.0             5.0     27.9
# 4  2017-01-19  10:00:00              NaN             5.0     27.5
#
#    TEMP_MIN(C)  TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  \
# 0          9.9         50.2                  NaN          35.5   52.0
# 1          NaN          NaN                  NaN           NaN    NaN
# 2         28.0         28.5                  NaN          17.3   51.0
# 3         27.9         28.5                  NaN          19.4   60.0
# 4         27.6         27.9                  NaN          21.8   71.0
#
#    WIND_DIR(deg)  WIND_SPEED(kt)  SLP(hPa)  MSLP(hPa)  SUNSHINE  Unnamed: 15  \
# ...

# %%
data1.drop(['DATE','TIME(UTC)'], axis=1)
# Out:
#       RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  TEMP_MAX(C)  \
# 0                 0.0             0.0     47.6          9.9         50.2
# 1                 NaN             0.0      NaN          NaN          NaN
# 2                 5.0             5.0     28.4         28.0         28.5
# 3                 0.0             5.0     27.9         27.9         28.5
# 4                 NaN             5.0     27.5         27.6         27.9
# ...               ...             ...      ...          ...          ...
# 6578              0.0             0.0     27.8         27.5         28.4
# 6579             18.0             0.0      1.6          0.0         25.4
# 6580              0.0             0.0     25.6         25.6         27.2
# 6581              0.0             0.0     24.8         24.8         25.6
# 6582              0.0             0.0     24.4         24.4         24.8
#
#       TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  WIND_DIR(deg)  WIND_SPEED(kt)  \
# ...

# %%
# Change column name of target
data1['rain_amt']=data1['RAIN_DAILY(mm)']

# %%
data1.drop(['RAIN_DAILY(mm)'], axis=1)
# Out:
#             DATE TIME(UTC)  RAIN_HOURLY(mm)  TEMP(C)  TEMP_MIN(C)  \
# 0     2017-01-19  06:00:00              0.0     47.6          9.9
# 1     2017-01-19  07:00:00              NaN      NaN          NaN
# 2     2017-01-19  08:00:00              5.0     28.4         28.0
# 3     2017-01-19  09:00:00              0.0     27.9         27.9
# 4     2017-01-19  10:00:00              NaN     27.5         27.6
# ...          ...       ...              ...      ...          ...
# 6578  2017-12-31  10:00:00              0.0     27.8         27.5
# 6579  2017-12-31  11:00:00             18.0      1.6          0.0
# 6580  2017-12-31  12:00:00              0.0     25.6         25.6
# 6581  2017-12-31  13:00:00              0.0     24.8         24.8
# 6582  2017-12-31  14:00:00              0.0     24.4         24.4
#
#       TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  WIND_DIR(deg)  \
# 0            50.2                  NaN          35.5   52.0          138.0
# ...

# %%
X_full=pd.read_csv("MAHARASHTRA_MUMBAI_CITY_MUMBAI_COLABA_18.8978_72.8128_11.98_2017-01-01_2022-08-10_AWS.csv")
X_test_full=pd.read_csv("MAHARASHTRA_MUMBAI_CITY_MUMBAI_COLABA_18.8978_72.8128_11.98_2017-01-01_2022-08-10_AWS.csv")

# %%
X_full["date_time"]=X_full["DATE"]+" "+X_full["TIME(UTC)"]
X_test_full["date_time"]=X_test_full["DATE"]+" "+X_test_full["TIME(UTC)"]

# %%
X_full.set_index("date_time")
X_test_full.set_index("date_time")
# Out:
#                            DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  \
# date_time
# 2017-01-19 06:00:00  2017-01-19  06:00:00              0.0             0.0
# 2017-01-19 07:00:00  2017-01-19  07:00:00              NaN             0.0
# 2017-01-19 08:00:00  2017-01-19  08:00:00              5.0             5.0
# 2017-01-19 09:00:00  2017-01-19  09:00:00              0.0             5.0
# 2017-01-19 10:00:00  2017-01-19  10:00:00              NaN             5.0
# ...                         ...       ...              ...             ...
# 2017-12-31 10:00:00  2017-12-31  10:00:00              0.0             0.0
# 2017-12-31 11:00:00  2017-12-31  11:00:00             18.0             0.0
# 2017-12-31 12:00:00  2017-12-31  12:00:00              0.0             0.0
# 2017-12-31 13:00:00  2017-12-31  13:00:00              0.0             0.0
# 2017-12-31 14:00:00  2017-12-31  14:00:00              0.0             0.0
#
# ...

# %%
X_full.drop(['DATE','TIME(UTC)'], axis=1)
X_test_full.drop(['DATE','TIME(UTC)'], axis=1)
# Out:
#       RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  TEMP_MAX(C)  \
# 0                 0.0             0.0     47.6          9.9         50.2
# 1                 NaN             0.0      NaN          NaN          NaN
# 2                 5.0             5.0     28.4         28.0         28.5
# 3                 0.0             5.0     27.9         27.9         28.5
# 4                 NaN             5.0     27.5         27.6         27.9
# ...               ...             ...      ...          ...          ...
# 6578              0.0             0.0     27.8         27.5         28.4
# 6579             18.0             0.0      1.6          0.0         25.4
# 6580              0.0             0.0     25.6         25.6         27.2
# 6581              0.0             0.0     24.8         24.8         25.6
# 6582              0.0             0.0     24.4         24.4         24.8
#
#       TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  WIND_DIR(deg)  WIND_SPEED(kt)  \
# ...

# %%
X_full['rain_amt']=X_full['RAIN_DAILY(mm)']
X_test_full['rain_amt']=X_test_full['RAIN_DAILY(mm)']

# %%
X_full.drop(['RAIN_DAILY(mm)'], axis=1, inplace=True)
X_test_full.drop(['RAIN_DAILY(mm)'], axis=1, inplace=True)

# %%
X_full.dropna(axis=0, subset=['rain_amt'], inplace=True)
y=X_full.rain_amt
X_full.drop(['rain_amt'], axis=1, inplace=True)

# %%
X_full.head()
# Out:
#          DATE TIME(UTC)  RAIN_HOURLY(mm)  TEMP(C)  TEMP_MIN(C)  TEMP_MAX(C)  \
# 0  2017-01-19  06:00:00              0.0     47.6          9.9         50.2
# 1  2017-01-19  07:00:00              NaN      NaN          NaN          NaN
# 2  2017-01-19  08:00:00              5.0     28.4         28.0         28.5
# 3  2017-01-19  09:00:00              0.0     27.9         27.9         28.5
# 4  2017-01-19  10:00:00              NaN     27.5         27.6         27.9
#
#    TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  WIND_DIR(deg)  WIND_SPEED(kt)  \
# 0                  NaN          35.5   52.0          138.0             1.0
# 1                  NaN           NaN    NaN            0.0             0.0
# 2                  NaN          17.3   51.0          243.0             1.0
# 3                  NaN          19.4   60.0          290.0             2.0
# 4                  NaN          21.8   71.0          324.0             2.0
#
# ...

# %%
X=X_full.select_dtypes(include=['float64','object'])
X_test=X_test_full.select_dtypes(include=['float64','object'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                      random_state=0)

# %%
X_train.head()
# Out:
#             DATE TIME(UTC)  RAIN_HOURLY(mm)  TEMP(C)  TEMP_MIN(C)  \
# 3217  2017-07-10  16:00:00              0.0     28.5         27.8
# 2165  2017-05-26  08:00:00              0.0     34.8         33.4
# 4245  2017-08-25  02:00:00              3.0     26.4         25.6
# 2948  2017-06-29  10:00:00              1.0     29.4         26.9
# 1862  2017-05-13  17:00:00              0.0     30.3         30.1
#
#       TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  WIND_DIR(deg)  \
# 3217         28.6                  NaN          27.0   92.0          249.0
# 2165         34.9                  NaN          28.3   69.0          322.0
# 4245         26.5                  NaN          26.4  100.0          323.0
# 2948         29.3                  NaN          29.0   98.0          255.0
# 1862         30.4                  NaN          27.7   86.0          151.0
#
#       WIND_SPEED(kt)  SLP(hPa)  MSLP(hPa)  SUNSHINE  Unnamed: 15  \
# ...

# %%
print(X_train.shape)
# Out:
# (5262, 16)

# %%
missing_val_count_by_column = (X_train.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# RAIN_HOURLY(mm)           9
# TEMP(C)                  16
# TEMP_MIN(C)              15
# TEMP_MAX(C)              26
# TEMP_MIN_MAX_DAY(C)    4885
# DEW_POINT(C)             84
# RH(%)                    66
# WIND_DIR(deg)             2
# WIND_SPEED(kt)            4
# SLP(hPa)                 34
# MSLP(hPa)                35
# Unnamed: 15            5262
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

my_imputer=SimpleImputer()

imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))

imputed_X_train.columns = X_train.columns
imputed_X_valid.columns = X_valid.columns
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 5
#       1 from sklearn.impute import SimpleImputer
#       3 my_imputer=SimpleImputer()
# ----> 5 imputed_X_train = pd.DataFrame(my_imputer.fit_transform(X_train))
#       6 imputed_X_valid = pd.DataFrame(my_imputer.transform(X_valid))
#       8 imputed_X_train.columns = X_train.columns
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\_set_output.py:142, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     140 @wraps(f)
#     141 def wrapped(self, X, *args, **kwargs):
# --> 142     data_to_wrap = f(self, X, *args, **kwargs)
#     143     if isinstance(data_to_wrap, tuple):
#     144         # only wrap the first output for cross decomposition
#     145         return (
#     146             _wrap_data_with_container(method, data_to_wrap[0], X, self),
# ...

# %%
# Leaving this trial incomplete---------------------------------------------------------------------------------------
