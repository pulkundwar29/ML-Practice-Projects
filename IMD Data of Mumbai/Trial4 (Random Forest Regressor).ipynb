# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("MAHARASHTRA_MUMBAI_CITY_MUMBAI_COLABA_18.8978_72.8128_11.98_2017-01-01_2022-08-10_AWS.csv")
df2=pd.read_csv("MAHARASHTRA_MUMBAI_CITY_MUMBAI_COLABA_18.8978_72.8128_11.98_2017-01-01_2022-08-10_AWS2.csv")
# Out:
# C:\Users\iamps\AppData\Local\Temp\ipykernel_18808\3832587508.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2=pd.read_csv("MAHARASHTRA_MUMBAI_CITY_MUMBAI_COLABA_18.8978_72.8128_11.98_2017-01-01_2022-08-10_AWS2.csv")

# %%
df1
# Out:
#             DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  \
# 0     2017-01-19  06:00:00              0.0             0.0     47.6
# 1     2017-01-19  07:00:00              NaN             0.0      NaN
# 2     2017-01-19  08:00:00              5.0             5.0     28.4
# 3     2017-01-19  09:00:00              0.0             5.0     27.9
# 4     2017-01-19  10:00:00              NaN             5.0     27.5
# ...          ...       ...              ...             ...      ...
# 6578  2017-12-31  10:00:00              0.0             0.0     27.8
# 6579  2017-12-31  11:00:00             18.0             0.0      1.6
# 6580  2017-12-31  12:00:00              0.0             0.0     25.6
# 6581  2017-12-31  13:00:00              0.0             0.0     24.8
# 6582  2017-12-31  14:00:00              0.0             0.0     24.4
#
#       TEMP_MIN(C)  TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  \
# ...

# %%
df1["date_time"]=df1["DATE"]+" " +df1["TIME(UTC)"]

# %%
df1
# Out:
#             DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  \
# 0     2017-01-19  06:00:00              0.0             0.0     47.6
# 1     2017-01-19  07:00:00              NaN             0.0      NaN
# 2     2017-01-19  08:00:00              5.0             5.0     28.4
# 3     2017-01-19  09:00:00              0.0             5.0     27.9
# 4     2017-01-19  10:00:00              NaN             5.0     27.5
# ...          ...       ...              ...             ...      ...
# 6578  2017-12-31  10:00:00              0.0             0.0     27.8
# 6579  2017-12-31  11:00:00             18.0             0.0      1.6
# 6580  2017-12-31  12:00:00              0.0             0.0     25.6
# 6581  2017-12-31  13:00:00              0.0             0.0     24.8
# 6582  2017-12-31  14:00:00              0.0             0.0     24.4
#
#       TEMP_MIN(C)  TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6583 entries, 0 to 6582
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE                 6583 non-null   object
#  1   TIME(UTC)            6583 non-null   object
#  2   RAIN_HOURLY(mm)      6572 non-null   float64
#  3   RAIN_DAILY(mm)       6578 non-null   float64
#  4   TEMP(C)              6558 non-null   float64
#  5   TEMP_MIN(C)          6564 non-null   float64
#  6   TEMP_MAX(C)          6550 non-null   float64
#  7   TEMP_MIN_MAX_DAY(C)  489 non-null    float64
#  8   DEW_POINT(C)         6480 non-null   float64
#  9   RH(%)                6505 non-null   float64
#  10  WIND_DIR(deg)        6580 non-null   float64
#  11  WIND_SPEED(kt)       6576 non-null   float64
#  12  SLP(hPa)             6535 non-null   float64
#  13  MSLP(hPa)            6534 non-null   float64
#  14  SUNSHINE             6583 non-null   float64
# ...

# %%
df1["date_time"]=pd.to_datetime(df1["date_time"])

# %%
df1
# Out:
#             DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  \
# 0     2017-01-19  06:00:00              0.0             0.0     47.6
# 1     2017-01-19  07:00:00              NaN             0.0      NaN
# 2     2017-01-19  08:00:00              5.0             5.0     28.4
# 3     2017-01-19  09:00:00              0.0             5.0     27.9
# 4     2017-01-19  10:00:00              NaN             5.0     27.5
# ...          ...       ...              ...             ...      ...
# 6578  2017-12-31  10:00:00              0.0             0.0     27.8
# 6579  2017-12-31  11:00:00             18.0             0.0      1.6
# 6580  2017-12-31  12:00:00              0.0             0.0     25.6
# 6581  2017-12-31  13:00:00              0.0             0.0     24.8
# 6582  2017-12-31  14:00:00              0.0             0.0     24.4
#
#       TEMP_MIN(C)  TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  \
# ...

# %%
df1=df1.set_index("date_time")

# %%
df1
# Out:
#                            DATE TIME(UTC)  RAIN_HOURLY(mm)  RAIN_DAILY(mm)  \
# date_time
# 2017-01-19 06:00:00  2017-01-19  06:00:00              0.0             0.0
# 2017-01-19 07:00:00  2017-01-19  07:00:00              NaN             0.0
# 2017-01-19 08:00:00  2017-01-19  08:00:00              5.0             5.0
# 2017-01-19 09:00:00  2017-01-19  09:00:00              0.0             5.0
# 2017-01-19 10:00:00  2017-01-19  10:00:00              NaN             5.0
# ...                         ...       ...              ...             ...
# 2017-12-31 10:00:00  2017-12-31  10:00:00              0.0             0.0
# 2017-12-31 11:00:00  2017-12-31  11:00:00             18.0             0.0
# 2017-12-31 12:00:00  2017-12-31  12:00:00              0.0             0.0
# 2017-12-31 13:00:00  2017-12-31  13:00:00              0.0             0.0
# 2017-12-31 14:00:00  2017-12-31  14:00:00              0.0             0.0
#
# ...

# %%
df1=df1.drop(["DATE","TIME(UTC)"],axis=1)

# %%
df1
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  \
# date_time
# 2017-01-19 06:00:00              0.0             0.0     47.6          9.9
# 2017-01-19 07:00:00              NaN             0.0      NaN          NaN
# 2017-01-19 08:00:00              5.0             5.0     28.4         28.0
# 2017-01-19 09:00:00              0.0             5.0     27.9         27.9
# 2017-01-19 10:00:00              NaN             5.0     27.5         27.6
# ...                              ...             ...      ...          ...
# 2017-12-31 10:00:00              0.0             0.0     27.8         27.5
# 2017-12-31 11:00:00             18.0             0.0      1.6          0.0
# 2017-12-31 12:00:00              0.0             0.0     25.6         25.6
# 2017-12-31 13:00:00              0.0             0.0     24.8         24.8
# 2017-12-31 14:00:00              0.0             0.0     24.4         24.4
#
# ...

# %%
df1=df1.resample("H").mean().interpolate(method="linear", limit_direction="forward")

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8313 entries, 2017-01-19 06:00:00 to 2017-12-31 14:00:00
# Freq: H
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RAIN_HOURLY(mm)      8313 non-null   float64
#  1   RAIN_DAILY(mm)       8313 non-null   float64
#  2   TEMP(C)              8313 non-null   float64
#  3   TEMP_MIN(C)          8313 non-null   float64
#  4   TEMP_MAX(C)          8313 non-null   float64
#  5   TEMP_MIN_MAX_DAY(C)  8307 non-null   float64
#  6   DEW_POINT(C)         8313 non-null   float64
#  7   RH(%)                8313 non-null   float64
#  8   WIND_DIR(deg)        8313 non-null   float64
#  9   WIND_SPEED(kt)       8313 non-null   float64
#  10  SLP(hPa)             8313 non-null   float64
#  11  MSLP(hPa)            8313 non-null   float64
#  12  SUNSHINE             8313 non-null   float64
#  13  Unnamed: 15          0 non-null      float64
# ...

# %%
df1
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  \
# date_time
# 2017-01-19 06:00:00              0.0             0.0     47.6         9.90
# 2017-01-19 07:00:00              2.5             0.0     38.0        18.95
# 2017-01-19 08:00:00              5.0             5.0     28.4        28.00
# 2017-01-19 09:00:00              0.0             5.0     27.9        27.90
# 2017-01-19 10:00:00              0.0             5.0     27.5        27.60
# ...                              ...             ...      ...          ...
# 2017-12-31 10:00:00              0.0             0.0     27.8        27.50
# 2017-12-31 11:00:00             18.0             0.0      1.6         0.00
# 2017-12-31 12:00:00              0.0             0.0     25.6        25.60
# 2017-12-31 13:00:00              0.0             0.0     24.8        24.80
# 2017-12-31 14:00:00              0.0             0.0     24.4        24.40
#
# ...

# %%
df2["date_time"]=df2["DATE"]+" "+df2["TIME(UTC)"]

# %%
df2=df2.set_index("date_time")

# %%
df2=df2.drop(["DATE","TIME(UTC)"],axis=1)

# %%
df2
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  \
# date_time
# 2018-01-01 5:00:00               0.0             0.0     24.9         23.7
# 2018-01-01 6:00:00               0.0             0.0     39.4         24.8
# 2018-01-01 7:00:00               0.0             0.0     27.8         26.6
# 2018-01-01 8:00:00               0.0             0.0     26.9         26.9
# 2018-01-01 9:00:00               0.0             0.0     26.8         26.6
# ...                              ...             ...      ...          ...
# 2022-08-10 10:45:00              NaN             1.5     27.5         25.5
# 2022-08-10 11:00:00              NaN             2.5     26.7         25.5
# 2022-08-10 11:15:00              NaN             3.0     25.6         25.5
# 2022-08-10 11:30:00              NaN             3.0     26.3         25.5
# 2022-08-10 11:45:00              NaN             3.0     26.7         25.5
#
# ...

# %%
df2=df2.reset_index()

# %%
df2["date_time"]=pd.to_datetime(df2["date_time"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114158 entries, 0 to 114157
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   date_time              114158 non-null  datetime64[ns]
#  1   RAIN_HOURLY(mm)        40207 non-null   float64
#  2   RAIN_DAILY(mm)         114157 non-null  float64
#  3   TEMP(C)                114150 non-null  float64
#  4   TEMP_MIN(C)            113930 non-null  float64
#  5   TEMP_MAX(C)            114059 non-null  float64
#  6   TEMP_MIN_MAX_DAY(C)    3084 non-null    float64
#  7   DEW_POINT(C)           114116 non-null  float64
#  8   RH(%)                  114113 non-null  float64
#  9   RH_MIN_MAX_DAY(%)      0 non-null       float64
#  10  WIND_DIR_10m(deg)      112308 non-null  float64
#  11  WIND_SPEED_10m(kt)     112308 non-null  float64
#  12  WIND_MAX/GUST_10m(kt)  96436 non-null   object
#  13  SLP(hPa)               114121 non-null  float64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8313 entries, 2017-01-19 06:00:00 to 2017-12-31 14:00:00
# Freq: H
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RAIN_HOURLY(mm)      8313 non-null   float64
#  1   RAIN_DAILY(mm)       8313 non-null   float64
#  2   TEMP(C)              8313 non-null   float64
#  3   TEMP_MIN(C)          8313 non-null   float64
#  4   TEMP_MAX(C)          8313 non-null   float64
#  5   TEMP_MIN_MAX_DAY(C)  8307 non-null   float64
#  6   DEW_POINT(C)         8313 non-null   float64
#  7   RH(%)                8313 non-null   float64
#  8   WIND_DIR(deg)        8313 non-null   float64
#  9   WIND_SPEED(kt)       8313 non-null   float64
#  10  SLP(hPa)             8313 non-null   float64
#  11  MSLP(hPa)            8313 non-null   float64
#  12  SUNSHINE             8313 non-null   float64
#  13  Unnamed: 15          0 non-null      float64
# ...

# %%
df2.set_index("date_time")
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  \
# date_time
# 2018-01-01 05:00:00              0.0             0.0     24.9         23.7
# 2018-01-01 06:00:00              0.0             0.0     39.4         24.8
# 2018-01-01 07:00:00              0.0             0.0     27.8         26.6
# 2018-01-01 08:00:00              0.0             0.0     26.9         26.9
# 2018-01-01 09:00:00              0.0             0.0     26.8         26.6
# ...                              ...             ...      ...          ...
# 2022-08-10 10:45:00              NaN             1.5     27.5         25.5
# 2022-08-10 11:00:00              NaN             2.5     26.7         25.5
# 2022-08-10 11:15:00              NaN             3.0     25.6         25.5
# 2022-08-10 11:30:00              NaN             3.0     26.3         25.5
# 2022-08-10 11:45:00              NaN             3.0     26.7         25.5
#
# ...

# %%
df2=df2.set_index("date_time")

# %%
df2=df2.resample("H").mean().interpolate(method="linear",limit_direction="forward")
# Out:
# C:\Users\iamps\AppData\Local\Temp\ipykernel_18808\1538936290.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2=df2.resample("H").mean().interpolate(method="linear",limit_direction="forward")

# %%
df2.tail()
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  \
# date_time
# 2022-08-10 07:00:00              0.0           0.000   27.800         26.1
# 2022-08-10 08:00:00              0.0           0.125   26.500         25.8
# 2022-08-10 09:00:00              0.0           1.125   26.150         25.5
# 2022-08-10 10:00:00              0.0           1.500   27.125         25.5
# 2022-08-10 11:00:00              0.0           2.875   26.325         25.5
#
#                      TEMP_MAX(C)  TEMP_MIN_MAX_DAY(C)  DEW_POINT(C)  RH(%)  \
# date_time
# 2022-08-10 07:00:00         28.1                 28.2        25.500  87.50
# 2022-08-10 08:00:00         28.1                 28.2        24.100  87.00
# 2022-08-10 09:00:00         28.1                 28.2        24.250  89.50
# 2022-08-10 10:00:00         28.1                 28.2        25.275  89.75
# 2022-08-10 11:00:00         28.1                 28.2        24.275  88.75
#
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 40375 entries, 2018-01-01 05:00:00 to 2022-08-10 11:00:00
# Freq: H
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RAIN_HOURLY(mm)      40375 non-null  float64
#  1   RAIN_DAILY(mm)       40375 non-null  float64
#  2   TEMP(C)              40375 non-null  float64
#  3   TEMP_MIN(C)          40375 non-null  float64
#  4   TEMP_MAX(C)          40375 non-null  float64
#  5   TEMP_MIN_MAX_DAY(C)  40368 non-null  float64
#  6   DEW_POINT(C)         40375 non-null  float64
#  7   RH(%)                40375 non-null  float64
#  8   RH_MIN_MAX_DAY(%)    0 non-null      float64
#  9   WIND_DIR_10m(deg)    40375 non-null  float64
#  10  WIND_SPEED_10m(kt)   40375 non-null  float64
#  11  SLP(hPa)             40375 non-null  float64
#  12  MSLP(hPa)            40375 non-null  float64
#  13  SUNSHINE(HH:MM)      40375 non-null  float64
# ...

# %%
df=pd.concat([df1,df2],axis=0)

# %%
df
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  \
# date_time
# 2017-01-19 06:00:00              0.0           0.000   47.600         9.90
# 2017-01-19 07:00:00              2.5           0.000   38.000        18.95
# 2017-01-19 08:00:00              5.0           5.000   28.400        28.00
# 2017-01-19 09:00:00              0.0           5.000   27.900        27.90
# 2017-01-19 10:00:00              0.0           5.000   27.500        27.60
# ...                              ...             ...      ...          ...
# 2022-08-10 07:00:00              0.0           0.000   27.800        26.10
# 2022-08-10 08:00:00              0.0           0.125   26.500        25.80
# 2022-08-10 09:00:00              0.0           1.125   26.150        25.50
# 2022-08-10 10:00:00              0.0           1.500   27.125        25.50
# 2022-08-10 11:00:00              0.0           2.875   26.325        25.50
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48688 entries, 2017-01-19 06:00:00 to 2022-08-10 11:00:00
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   RAIN_HOURLY(mm)      48688 non-null  float64
#  1   RAIN_DAILY(mm)       48688 non-null  float64
#  2   TEMP(C)              48688 non-null  float64
#  3   TEMP_MIN(C)          48688 non-null  float64
#  4   TEMP_MAX(C)          48688 non-null  float64
#  5   TEMP_MIN_MAX_DAY(C)  48675 non-null  float64
#  6   DEW_POINT(C)         48688 non-null  float64
#  7   RH(%)                48688 non-null  float64
#  8   WIND_DIR(deg)        8313 non-null   float64
#  9   WIND_SPEED(kt)       8313 non-null   float64
#  10  SLP(hPa)             48688 non-null  float64
#  11  MSLP(hPa)            48688 non-null  float64
#  12  SUNSHINE             8313 non-null   float64
#  13  Unnamed: 15          0 non-null      float64
# ...

# %%
df=df.resample("H").mean().interpolate(method="linear",limit_direction="forward")

# %%
df
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)  TEMP(C)  TEMP_MIN(C)  \
# date_time
# 2017-01-19 06:00:00              0.0           0.000   47.600         9.90
# 2017-01-19 07:00:00              2.5           0.000   38.000        18.95
# 2017-01-19 08:00:00              5.0           5.000   28.400        28.00
# 2017-01-19 09:00:00              0.0           5.000   27.900        27.90
# 2017-01-19 10:00:00              0.0           5.000   27.500        27.60
# ...                              ...             ...      ...          ...
# 2022-08-10 07:00:00              0.0           0.000   27.800        26.10
# 2022-08-10 08:00:00              0.0           0.125   26.500        25.80
# 2022-08-10 09:00:00              0.0           1.125   26.150        25.50
# 2022-08-10 10:00:00              0.0           1.500   27.125        25.50
# 2022-08-10 11:00:00              0.0           2.875   26.325        25.50
#
# ...

# %%
df.corr()
# Out:
#                      RAIN_HOURLY(mm)  RAIN_DAILY(mm)   TEMP(C)  TEMP_MIN(C)  \
# RAIN_HOURLY(mm)             1.000000        0.062219 -0.016593    -0.001347
# RAIN_DAILY(mm)              0.062219        1.000000 -0.056155    -0.078778
# TEMP(C)                    -0.016593       -0.056155  1.000000     0.827065
# TEMP_MIN(C)                -0.001347       -0.078778  0.827065     1.000000
# TEMP_MAX(C)                -0.018241       -0.065747  0.822769     0.743245
# TEMP_MIN_MAX_DAY(C)        -0.005804       -0.073107  0.508851     0.601236
# DEW_POINT(C)                0.019615        0.081635  0.590387     0.584472
# RH(%)                       0.041575        0.173204 -0.241036    -0.106369
# WIND_DIR(deg)              -0.018252        0.010998  0.067452     0.024614
# WIND_SPEED(kt)              0.077415        0.012017  0.003525    -0.008499
# SLP(hPa)                   -0.037957       -0.214913 -0.227143    -0.294891
# ...

# %%
df=df.rename(columns={"date_time":"ds","TEMP(C)":"y"})

# %%
df=df.drop(["TEMP_MIN(C)","TEMP_MAX(C)","TEMP_MIN_MAX_DAY(C)","WIND_DIR(deg)","WIND_SPEED(kt)","SUNSHINE","Unnamed: 15","RH_MIN_MAX_DAY(%)","WIND_DIR_10m(deg)","WIND_SPEED_10m(kt)","SUNSHINE(HH:MM)","Unnamed: 17"],axis=1)

# %%
Pred_features = ['RAIN_HOURLY(mm)', 'RAIN_DAILY(mm)', 'DEW_POINT(C)', 'RH(%)', 'SLP(hPa)', 'MSLP(hPa)']
X = df[Pred_features]
y = df.y

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
# Finding MAE for Decision Tree Regression
pred = DecisionTreeRegressor(random_state=1)
pred.fit(X,y)
val_mae = mean_absolute_error(, val_y)
print("Validation MAE for best value of max_leaf_nodes: {:,.0f}".format(val_mae))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 6
#       4 pred = DecisionTreeRegressor(random_state=1)
#       5 pred.fit(X,y)
# ----> 6 val_mae = mean_absolute_error(val_predictions, val_y)
#       7 print("Validation MAE for best value of max_leaf_nodes: {:,.0f}".format(val_mae))
#
# NameError: name 'mean_absolute_error' is not defined
