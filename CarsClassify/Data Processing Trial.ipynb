# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ttn = pd.read_csv('train.csv')

# %%
ttn.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
ttn.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ttn.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
print(ttn.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None

# %%
nttn = ttn.dropna()

# %%
print(nttn.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB
# None

# %%
ttn.fillna(200, inplace = False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0      1
# 2                               Heikkinen, Miss. Laina  female   26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0      1
# 4                             Allen, Mr. William Henry    male   35.0      0
# ...

# %%
ttn.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ttn['Age'].mode()[0]
# Out:
# 24.0

# %%
ttn.loc[2, 'Age'] = 26

# %%
ttn.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
for x in ttn.index:
  if ttn.loc[x, "Fare"] < 6:
    ttn.loc[x, "Fare"] = 9999

# %%
print(ttn.loc[[179]])
# Out:
#      PassengerId  Survived  Pclass                 Name   Sex   Age  SibSp  \
# 179          180         0       3  Leonard, Mr. Lionel  male  36.0      0
#
#      Parch Ticket    Fare Cabin Embarked
# 179      0   LINE  9999.0   NaN        S

# %%
ttn[67:71]
# Out:
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 67           68         0       3         Crease, Mr. Ernest James    male
# 68           69         1       3  Andersson, Miss. Erna Alexandra  female
# 69           70         0       3                Kink, Mr. Vincenz    male
# 70           71         0       2       Jenkin, Mr. Stephen Curnow    male
#
#      Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 67  19.0      0      0   S.P. 3464   8.1583   NaN        S
# 68  17.0      4      2     3101281   7.9250   NaN        S
# 69  26.0      2      0      315151   8.6625   NaN        S
# 70  32.0      0      0  C.A. 33111  10.5000   NaN        S

# %%
cust = ttn[['Age', 'Name', 'Sex', 'Fare']]

# %%
print(cust)
# Out:
#       Age                                               Name     Sex     Fare
# 0    22.0                            Braund, Mr. Owen Harris    male   7.2500
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  71.2833
# 2    26.0                             Heikkinen, Miss. Laina  female   7.9250
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  53.1000
# 4    35.0                           Allen, Mr. William Henry    male   8.0500
# ..    ...                                                ...     ...      ...
# 886  27.0                              Montvila, Rev. Juozas    male  13.0000
# 887  19.0                       Graham, Miss. Margaret Edith  female  30.0000
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"  female  23.4500
# 889  26.0                              Behr, Mr. Karl Howell    male  30.0000
# 890  32.0                                Dooley, Mr. Patrick    male   7.7500
#
# [891 rows x 4 columns]

# %%
ttn[((ttn['Age'] <= 18))]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 7              8         0       3        Palsson, Master. Gosta Leonard
# 9             10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3       Sandstrom, Miss. Marguerite Rut
# 14            15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                  Rice, Master. Eugene
# ..           ...       ...     ...                                   ...
# 852          853         0       3               Boulos, Miss. Nourelain
# 853          854         1       1             Lines, Miss. Mary Conover
# 855          856         1       3            Aks, Mrs. Sam (Leah Rosen)
# 869          870         1       3       Johnson, Master. Harold Theodor
# 875          876         1       3      Najib, Miss. Adele Kiamie "Jane"
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
ttn.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ttn[['Last_Name', 'First_Name']] = ttn['Name'].str.split(',', expand = True)
ttn.drop(['Name'], axis = 1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0              1         0       3    male  22.0      1      0
# 1              2         1       1  female  38.0      1      0
# 2              3         1       3  female  26.0      0      0
# 3              4         1       1  female  35.0      1      0
# 4              5         0       3    male  35.0      0      0
# ..           ...       ...     ...     ...   ...    ...    ...
# 886          887         0       2    male  27.0      0      0
# 887          888         1       1  female  19.0      0      0
# 888          889         0       3  female   NaN      1      2
# 889          890         1       1    male  26.0      0      0
# 890          891         0       3    male  32.0      0      0
#
#                Ticket     Fare Cabin Embarked  Last_Name  \
# 0           A/5 21171   7.2500   NaN        S     Braund
# 1            PC 17599  71.2833   C85        C    Cumings
# ...

# %%
ttn.drop_duplicates(inplace = True)

# %%
print(ttn.drop_duplicates(inplace = True))
# Out:
# None

# %%
ttn.corr()
# Out:
# C:\Users\iamps\AppData\Local\Temp\ipykernel_19728\3735149425.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ttn.corr()
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.045738 -0.084080 -0.081493  0.032055 -0.060542 -0.058361
#
#                  Fare
# PassengerId  0.045738
# Survived    -0.084080
# ...

# %%
ttn.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Last_Name  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
ttn.melt()
# Out:
#           variable                            value
# 0      PassengerId                                1
# 1      PassengerId                                2
# 2      PassengerId                                3
# 3      PassengerId                                4
# 4      PassengerId                                5
# ...            ...                              ...
# 12469   First_Name                      Rev. Juozas
# 12470   First_Name             Miss. Margaret Edith
# 12471   First_Name   Miss. Catherine Helen "Carrie"
# 12472   First_Name                  Mr. Karl Howell
# 12473   First_Name                      Mr. Patrick
#
# [12474 rows x 2 columns]

# %%
ttn.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
ttn.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ttn2=ttn.dropna()

# %%
ttn2.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked  Last_Name  \
# 1       0  PC 17599  71.2833   C85        C    Cumings
# 3       0    113803  53.1000  C123        S   Futrelle
# 6       0     17463  51.8625   E46        S   McCarthy
# 10      1   PP 9549  16.7000    G6        S  Sandstrom
# ...

# %%
tg1=ttn[['Survived', 'Sex']]

# %%
print(tg1)
# Out:
#      Survived     Sex
# 0           0    male
# 1           1  female
# 2           1  female
# 3           1  female
# 4           0    male
# ..        ...     ...
# 886         0    male
# 887         1  female
# 888         0  female
# 889         1    male
# 890         0    male
#
# [891 rows x 2 columns]

# %%
ttn.Survived.sum()
# Out:
# 342

# %%
ttn.Survived.value_counts().plot(kind='bar', alpha=0.5)
# Out:
# <AxesSubplot: >

# %%
plt.scatter(ttn.Survived, ttn.Age, alpha=1)

# %%
ttn.Pclass.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
for x in [1,2,3]:    
    ttn.Age[ttn.Pclass == x].plot(kind="kde")
plt.title("Age wrt Pclass")
plt.legend(("1st","2nd","3rd"))

# %%
ttn.dropna[['Age'].notna()]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\iamps\OneDrive\Desktop\NLI\#8 Data Processing\Data Processing Trial.ipynb Cell 38 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/iamps/OneDrive/Desktop/NLI/%238%20Data%20Processing/Data%20Processing%20Trial.ipynb#X52sZmlsZQ%3D%3D?line=0'>1</a> ttn.dropna[['Age'].notna()]
#
# AttributeError: 'list' object has no attribute 'notna'

# %%
g = sns.FacetGrid(ttn, col="Sex", row="Survived", margin_titles=True)
g.map(plt.hist, "Age",color="purple");

# %%
g = sns.FacetGrid(ttn, hue="Survived", col="Sex", margin_titles=True,
                palette="Set1",hue_kws=dict(marker=["^", "v"]))
g.map(plt.scatter, "Fare", "Age",edgecolor="w").add_legend()
plt.subplots_adjust(top=0.8)
plt.xlim(0,100)
g.fig.suptitle('Survival by Gender , Age and Fare');

# %%
tg2 = ttn[['Embarked', 'Survived']]

# %%
tg2.head()
# Out:
#   Embarked  Survived
# 0        S         0
# 1        C         1
# 2        S         1
# 3        S         1
# 4        S         0

# %%
ttn[ttn['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked Last_Name  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN     Icard
# 829  female  62.0      0      0  113572  80.0   B28      NaN     Stone
#
#                               First_Name
# 61                          Miss. Amelie
# 829   Mrs. George Nelson (Martha Evelyn)

# %%
sns.boxplot(x="Embarked", y="Fare", hue="Pclass", data=ttn);
plt.ylim(0,150)
# Out:
# (0.0, 150.0)

# %%
ttn["Embarked"] = ttn["Embarked"].fillna('C')

# %%
ttn.head(65)

# %%
ttn[ttn['Fare'].isnull()]

# %%
plt.scatter(ttn['Fare'], ttn['Pclass'], label = "The graph")
plt.xlim(0, 500)
plt.xlabel('Price in Euro')
plt.ylabel('Class')
plt.title("Price of each class")

# %%
plt.scatter(ttn['Pclass'], ttn['Fare'], color = 'purple', label = "Passenger Paid")
plt.ylabel('Price in Euro')
plt.xlabel('Class')
plt.title("Price of each class")
plt.ylim(0,200)

# %%
sns.displot(x='Age', data = ttn)

# %%
# filling empty Age cells with mean value
ttn['Age'].fillna(ttn['Age'].mean(), inplace = True)

# %%
sns.displot(x='Age', data = ttn)

# %%
ttn.Sex.value_counts().plot(kind = 'bar')

# %%
ttn[ttn.Sex=='female']

# %%
fig, axs = plt.subplots(1,2)
ttn[ttn.Sex=='male'].Survived.value_counts().plot(kind='barh', ax=axs[0], title='Male survivors')
ttn[ttn.Sex=='female'].Survived.value_counts().plot(kind='barh', ax=axs[1], title='Female survivors')

# %%
ttn[(ttn.Age<18) & (ttn.Sex=='male')].Survived.value_counts().plot(kind='barh')

# %%
ttn[(ttn.Age<18) & (ttn.Sex=='female')].Survived.value_counts().plot(kind='barh')

# %%
ttn.Age = ttn.Age.fillna(value=29)

# %%
print(ttn[ttn.Age==29])

# %%
ttn.head()
